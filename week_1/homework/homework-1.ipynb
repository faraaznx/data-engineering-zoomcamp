# %%
from pyspark.sql.functions import *

# %%
df = spark.read.format('csv').options(header=True, inferSchema=True).load("dbfs:/FileStore/gt_data/green_tripdata_2019-01.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.withColumn("lpep_pickup_datetime", to_timestamp(col("lpep_pickup_datetime"), "yyyy-MM-dd HH:mm:ss"))\
.withColumn("lpep_dropoff_datetime", to_timestamp(col("lpep_dropoff_datetime"), "yyyy-MM-dd HH:mm:ss"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- VendorID: integer (nullable = true)
# -- lpep_pickup_datetime: timestamp (nullable = true)
# -- lpep_dropoff_datetime: timestamp (nullable = true)
# -- store_and_fwd_flag: string (nullable = true)
# -- RatecodeID: integer (nullable = true)
# -- PULocationID: integer (nullable = true)
# -- DOLocationID: integer (nullable = true)
# -- passenger_count: integer (nullable = true)
# -- trip_distance: double (nullable = true)
# -- fare_amount: double (nullable = true)
# -- extra: double (nullable = true)
# -- mta_tax: double (nullable = true)
# -- tip_amount: double (nullable = true)
# -- tolls_amount: double (nullable = true)
# ...

# %%
df.write.saveAsTable("green_tbl")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_2 = spark.read.format('csv').options(header=True, inferSchema=True).load("dbfs:/FileStore/gt_data/taxi__zone_lookup__1_.csv")
df_2.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- LocationID: integer (nullable = true)
# -- Borough: string (nullable = true)
# -- Zone: string (nullable = true)
# -- service_zone: string (nullable = true)
#
# </div>

# %%
df_2.write.saveAsTable("lkp_tbl")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql SELECT COUNT(*) FROM  green_tbl WHERE LEFT(lpep_dropoff_datetime,10) = '2019-01-15'
AND LEFT(lpep_pickup_datetime,10) = '2019-01-15'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>20530</td></tr></tbody></table></div>

# %%
# %sql
SELECT LEFT(lpep_pickup_datetime,10), MAX(trip_distance) FROM green_tbl GROUP BY 1 ORDER BY 2 DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql SELECT COUNT(*) FROM green_tbl WHERE passenger_count = 3 AND LEFT(lpep_pickup_datetime,10) = '2019-01-01'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>254</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(CASE WHEN passenger_count = 2 THEN 1 ELSE 0 END) AS 2_pas, SUM(CASE WHEN passenger_count = 3 THEN 1 ELSE 0 END) AS 3_pas  FROM green_tbl
WHERE LEFT(lpep_pickup_datetime,10) = '2019-01-01'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>2_pas</th><th>3_pas</th></tr></thead><tbody><tr><td>1282</td><td>254</td></tr></tbody></table></div>

# %%
# %sql DESC green_tbl
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql SELECT * FROM lkp_tbl
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.select(df['total_amount'],df['lpep_dropoff_datetime']).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+---------------------+
# total_amount|lpep_dropoff_datetime|
# +------------+---------------------+
#          4.3|  2018-12-21 15:18:57|
#          7.3|  2019-01-01 00:16:32|
#          5.8|  2019-01-01 00:31:38|
#        19.71|  2019-01-01 01:04:54|
#         19.3|  2019-01-01 00:39:43|
#          7.8|  2019-01-01 00:19:09|
#         14.8|  2019-01-01 01:00:01|
#         17.3|  2019-01-01 00:30:50|
#         26.8|  2019-01-01 00:39:46|
#         16.8|  2019-01-01 01:19:02|
#        37.06|  2019-01-01 00:56:42|
#         9.36|  2019-01-01 00:21:00|
#         16.8|  2019-01-01 00:45:50|
# ...

# %%
# %sql
SELECT l.Zone AS pickup_zone, l2.Zone AS drop_zone, g.tip_amount FROM green_tbl g JOIN lkp_tbl l ON g.PULocationID = l.LocationID JOIN lkp_tbl l2 ON g.DOLocationID = l2.LocationId
WHERE l.Zone = "Astoria" 
ORDER BY 3 DESC 
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_zone</th><th>drop_zone</th><th>tip_amount</th></tr></thead><tbody><tr><td>Astoria</td><td>Long Island City/Queens Plaza</td><td>88.0</td></tr></tbody></table></div>
