# %%
from pyspark.sql.functions import *

# loading the csv files as Spark Dataframes
df = (
    spark.read.format("csv")
    .options(header=True, inferSchema=True)
    .load("dbfs:/FileStore/gt_data/green_tripdata_2019-01.csv")
)
df_2 = (
    spark.read.format("csv")
    .options(header=True, inferSchema=True)
    .load("dbfs:/FileStore/gt_data/taxi__zone_lookup__1_.csv")
)

# Converting two string columns into timestamps
df = df.withColumn(
    "lpep_pickup_datetime",
    to_timestamp(col("lpep_pickup_datetime"), "yyyy-MM-dd HH:mm:ss"),
).withColumn(
    "lpep_dropoff_datetime",
    to_timestamp(col("lpep_dropoff_datetime"), "yyyy-MM-dd HH:mm:ss"),
)


# Creating DeltaTables
df.write.saveAsTable("green_tbl")
df_2.write.saveAsTable("lkp_tbl")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT
  COUNT(*) AS count
FROM
  green_tbl
WHERE
  LEFT(lpep_dropoff_datetime, 10) = '2019-01-15'
  AND LEFT(lpep_pickup_datetime, 10) = '2019-01-15'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count</th></tr></thead><tbody><tr><td>20530</td></tr></tbody></table></div>

# %%
# %sql
SELECT
  LEFT(lpep_pickup_datetime, 10) AS date,
  trip_distance
FROM
  green_tbl
WHERE
  trip_distance = (
    SELECT
      MAX(trip_distance)
    FROM
      green_tbl
  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>trip_distance</th></tr></thead><tbody><tr><td>2019-01-15</td><td>117.99</td></tr></tbody></table></div>

# %%
# %sql
SELECT
  SUM(
    CASE
      WHEN passenger_count = 2 THEN 1
      ELSE 0
    END
  ) AS 2_pas,
  SUM(
    CASE
      WHEN passenger_count = 3 THEN 1
      ELSE 0
    END
  ) AS 3_pas
FROM
  green_tbl
WHERE
  LEFT(lpep_pickup_datetime, 10) = '2019-01-01'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>2_pas</th><th>3_pas</th></tr></thead><tbody><tr><td>1282</td><td>254</td></tr></tbody></table></div>

# %%
# %sql
SELECT
  l.Zone AS pickup_zone,
  l2.Zone AS drop_zone,
  g.tip_amount
FROM
  green_tbl g
  JOIN lkp_tbl l ON g.PULocationID = l.LocationID
  JOIN lkp_tbl l2 ON g.DOLocationID = l2.LocationId
WHERE
  l.Zone = "Astoria"
ORDER BY
  3 DESC
LIMIT
  1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_zone</th><th>drop_zone</th><th>tip_amount</th></tr></thead><tbody><tr><td>Astoria</td><td>Long Island City/Queens Plaza</td><td>88.0</td></tr></tbody></table></div>
